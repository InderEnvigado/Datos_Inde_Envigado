# %%
import pandas as pd
import numpy as np

# %%
# Ruta del archivo con los datos desde GitHub
file_INSCRITOSIE = 'https://raw.githubusercontent.com/InderEnvigado/Datos_Inde_Envigado/main/Informe_de_inscritos.xlsx'

# %%
# Archivo de Excel
INSCRITOSIE = pd.read_excel(file_INSCRITOSIE)

# %%
# DataFrame INSCRITOSIE
print(INSCRITOSIE.head())  # Muestra las primeras filas del DataFrame
# Out:
#        fecha  Inscripcion           Servicio  \
# 0 2018-01-17        89536  GIMNASIA INFANTIL
# 1 2018-01-17        89528  GIMNASIA INFANTIL
# 2 2018-01-17        89535  GIMNASIA INFANTIL
# 3 2018-01-17        89531           NATACIÓN
# 4 2018-01-17        89533  GIMNASIA INFANTIL
#
#                                                Nivel  \
# 0  INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1  PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2  NIVEL 2 (6-15AÑOS)                            ...
# 3  CALAMARES                                     ...
# 4  INICIACIÓN 2 (8-12)                           ...
#
#                                  nom_barrio  edad    Género  \
# 0                                       NaN    15  FEMENINO
# 1  EL DORADO                                   12  FEMENINO
# 2                                       NaN    16  FEMENINO
# 3                                       NaN     0  FEMENINO
# 4                                       NaN    15  FEMENINO
#
#                                                etnia  Poblacion  \
# 0                                                NaN        NaN
# 1  Mestiza                                       ...  No Aplica
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#                                            Escenario  ...  \
# 0  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
#
#                               eps  estrato  \
# 0                             NaN      NaN
# 1  SURA                                  3
# 2                             NaN      NaN
# 3                             NaN      NaN
# 4                             NaN      NaN
#
#                                cod_ciu  \
# 0                                  NaN
# 1  ENVIGADO
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                              tipo_documento  \
# 0                                       NaN
# 1  Registro Civil
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                  nacimiento     rh nacionalidad  \
# 0                                       NaN    NaN          NaN
# 1  ENVIGADO                                  A+             NaN
# 2                                       NaN    NaN          NaN
# 3                                       NaN    NaN          NaN
# 4                                       NaN    NaN          NaN
#
#                                 escolaridad diversidad  \
# 0                                       NaN  No Aplica
# 1  PREESCOLAR                                No Aplica
# 2                                       NaN  No Aplica
# 3                                       NaN  No Aplica
# 4                                       NaN  No Aplica
#
#                                            Población
# 0  NO APLICA                                     ...
# 1  NO APLICA                                     ...
# 2  NO APLICA                                     ...
# 3  NO APLICA                                     ...
# 4  NO APLICA                                     ...
#
# [5 rows x 24 columns]

# %% [markdown]
# **Exploración de datos**

# %%
#consultamos los datos del dataframe
INSCRITOSIE
# Out:
#             fecha  Inscripcion  \
# 0      2018-01-17        89536
# 1      2018-01-17        89528
# 2      2018-01-17        89535
# 3      2018-01-17        89531
# 4      2018-01-17        89533
# ...           ...          ...
# 120321 2025-03-28        94235
# 120322 2025-03-28        94240
# 120323 2025-03-28        94244
# 120324 2025-03-28        94247
# 120325 2025-03-28        94241
#
#                                                  Servicio  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                       nom_barrio  edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                                     cod_ciu  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      escolaridad        diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
# consultamos las columnas que tiene el dataframe
INSCRITOSIE.columns
# Out:
# Index(['fecha', 'Inscripcion', 'Servicio', 'Nivel', 'nom_barrio', 'edad',
#        'Género', 'etnia', 'Poblacion', 'Escenario', 'instructor', 'curso',
#        'zona', 'fecha_nacimiento', 'eps', 'estrato', 'cod_ciu',
#        'tipo_documento', 'nacimiento', 'rh', 'nacionalidad', 'escolaridad',
#        'diversidad', 'Población'],
#       dtype='object')

# %%
## comando describe para validar estadisticos descriptivos basicos
INSCRITOSIE.describe()
# Out:
#                                fecha   Inscripcion           edad  \
# count                         120326  1.203260e+05  120326.000000
# mean   2022-04-22 06:10:26.498013696  6.343167e+04      25.640585
# min              2018-01-17 00:00:00  1.980000e+02     -75.000000
# 25%              2021-02-02 00:00:00  3.053125e+04      11.000000
# 50%              2022-06-14 00:00:00  5.992500e+04      15.000000
# 75%              2024-03-12 00:00:00  9.102275e+04      39.000000
# max              2025-03-28 00:00:00  2.018045e+07     125.000000
# std                              NaN  1.781892e+05      21.850769
#
#               curso               fecha_nacimiento
# count  1.203260e+05                         116826
# mean   2.021980e+07  1998-05-02 16:14:11.235170304
# min    2.018001e+07            1900-01-01 00:00:00
# 25%    2.021000e+07            1984-02-17 00:00:00
# 50%    2.022125e+07            2008-12-08 00:00:00
# 75%    2.024038e+07            2013-09-16 00:00:00
# max    2.025122e+07            2099-09-10 00:00:00
# std    2.147757e+04                            NaN

# %%
#consultar el tipo de datos
print(INSCRITOSIE.dtypes)
# Out:
# fecha               datetime64[ns]
# Inscripcion                  int64
# Servicio                    object
# Nivel                       object
# nom_barrio                  object
# edad                         int64
# Género                      object
# etnia                       object
# Poblacion                   object
# Escenario                   object
# instructor                  object
# curso                        int64
# zona                        object
# fecha_nacimiento    datetime64[ns]
# eps                         object
# estrato                     object
# cod_ciu                     object
# tipo_documento              object
# nacimiento                  object
# rh                          object
# nacionalidad                object
# escolaridad                 object
# diversidad                  object
# Población                   object
# dtype: object

# %%
## Identificar valores nulos
INSCRITOSIE.isnull()
# Out:
#         fecha  Inscripcion  Servicio  Nivel  nom_barrio   edad  Género  etnia  \
# 0       False        False     False  False        True  False   False   True
# 1       False        False     False  False       False  False   False  False
# 2       False        False     False  False        True  False   False   True
# 3       False        False     False  False        True  False   False   True
# 4       False        False     False  False        True  False   False   True
# ...       ...          ...       ...    ...         ...    ...     ...    ...
# 120321  False        False     False  False       False  False   False  False
# 120322  False        False     False  False       False  False   False  False
# 120323  False        False     False  False       False  False   False  False
# 120324  False        False     False  False       False  False   False  False
# 120325  False        False     False  False       False  False   False  False
#
#         Poblacion  Escenario  ...    eps  estrato  cod_ciu  tipo_documento  \
# 0            True      False  ...   True     True     True            True
# 1           False      False  ...  False    False    False           False
# 2            True      False  ...   True     True     True            True
# 3            True      False  ...   True     True     True            True
# 4            True      False  ...   True     True     True            True
# ...           ...        ...  ...    ...      ...      ...             ...
# 120321      False      False  ...  False    False    False           False
# 120322      False      False  ...  False    False    False           False
# 120323      False      False  ...  False    False    False           False
# 120324      False      False  ...  False    False    False           False
# 120325      False      False  ...  False    False    False           False
#
#         nacimiento     rh  nacionalidad  escolaridad  diversidad  Población
# 0             True   True          True         True       False      False
# 1            False  False          True        False       False      False
# 2             True   True          True         True       False      False
# 3             True   True          True         True       False      False
# 4             True   True          True         True       False      False
# ...            ...    ...           ...          ...         ...        ...
# 120321        True  False         False        False       False      False
# 120322        True  False         False        False       False      False
# 120323        True  False         False        False       False      False
# 120324        True  False         False        False       False      False
# 120325        True  False         False        False       False      False
#
# [120326 rows x 24 columns]

# %%
# Validar nulos
INSCRITOSIE.isnull().sum()
# Out:
# fecha                    0
# Inscripcion              0
# Servicio                 0
# Nivel                    0
# nom_barrio           16064
# edad                     0
# Género                   0
# etnia                11637
# Poblacion            11651
# Escenario                0
# instructor               0
# curso                    0
# zona                 20730
# fecha_nacimiento      3500
# eps                  14885
# estrato              12565
# cod_ciu              15059
# tipo_documento       14584
# nacimiento          102411
# rh                   12343
# nacionalidad         21202
# escolaridad          13059
# diversidad             858
# Población                0
# dtype: int64

# %%
##Descripción de las columnas
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120326 entries, 0 to 120325
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   fecha             120326 non-null  datetime64[ns]
#  1   Inscripcion       120326 non-null  int64
#  2   Servicio          120326 non-null  object
#  3   Nivel             120326 non-null  object
#  4   nom_barrio        104262 non-null  object
#  5   edad              120326 non-null  int64
#  6   Género            120326 non-null  object
#  7   etnia             108689 non-null  object
#  8   Poblacion         108675 non-null  object
#  9   Escenario         120326 non-null  object
#  10  instructor        120326 non-null  object
#  11  curso             120326 non-null  int64
#  12  zona              99596 non-null   object
#  13  fecha_nacimiento  116826 non-null  datetime64[ns]
#  14  eps               105441 non-null  object
#  15  estrato           107761 non-null  object
#  16  cod_ciu           105267 non-null  object
#  17  tipo_documento    105742 non-null  object
#  18  nacimiento        17915 non-null   object
#  19  rh                107983 non-null  object
#  20  nacionalidad      99124 non-null   object
#  21  escolaridad       107267 non-null  object
#  22  diversidad        119468 non-null  object
#  23  Población         120326 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(19)
# memory usage: 22.0+ MB

# %%
# Mostramos las primeras filas del dataframe
INSCRITOSIE.head()
# Out:
#        fecha  Inscripcion           Servicio  \
# 0 2018-01-17        89536  GIMNASIA INFANTIL
# 1 2018-01-17        89528  GIMNASIA INFANTIL
# 2 2018-01-17        89535  GIMNASIA INFANTIL
# 3 2018-01-17        89531           NATACIÓN
# 4 2018-01-17        89533  GIMNASIA INFANTIL
#
#                                                Nivel  \
# 0  INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1  PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2  NIVEL 2 (6-15AÑOS)                            ...
# 3  CALAMARES                                     ...
# 4  INICIACIÓN 2 (8-12)                           ...
#
#                                  nom_barrio  edad    Género  \
# 0                                       NaN    15  FEMENINO
# 1  EL DORADO                                   12  FEMENINO
# 2                                       NaN    16  FEMENINO
# 3                                       NaN     0  FEMENINO
# 4                                       NaN    15  FEMENINO
#
#                                                etnia  Poblacion  \
# 0                                                NaN        NaN
# 1  Mestiza                                       ...  No Aplica
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#                                            Escenario  ...  \
# 0  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
#
#                               eps  estrato  \
# 0                             NaN      NaN
# 1  SURA                                  3
# 2                             NaN      NaN
# 3                             NaN      NaN
# 4                             NaN      NaN
#
#                                cod_ciu  \
# 0                                  NaN
# 1  ENVIGADO
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                              tipo_documento  \
# 0                                       NaN
# 1  Registro Civil
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                  nacimiento     rh nacionalidad  \
# 0                                       NaN    NaN          NaN
# 1  ENVIGADO                                  A+             NaN
# 2                                       NaN    NaN          NaN
# 3                                       NaN    NaN          NaN
# 4                                       NaN    NaN          NaN
#
#                                 escolaridad diversidad  \
# 0                                       NaN  No Aplica
# 1  PREESCOLAR                                No Aplica
# 2                                       NaN  No Aplica
# 3                                       NaN  No Aplica
# 4                                       NaN  No Aplica
#
#                                            Población
# 0  NO APLICA                                     ...
# 1  NO APLICA                                     ...
# 2  NO APLICA                                     ...
# 3  NO APLICA                                     ...
# 4  NO APLICA                                     ...
#
# [5 rows x 24 columns]

# %%
# verificar valores únicos en Barrio
print(INSCRITOSIE['nom_barrio'].unique())
# Out:
# [nan 'EL DORADO                               '
#  'NO APLICA                               '
#  'OTRO                                    '
#  'JARDINES                                '
#  'EL SALADO                               '
#  'MESA                             '
#  'PONTEVEDRA                              '
#  'LA MINA                                 '
#  'ALCALÁ                                  '
#  'LOS NARANJOS                            '
#  'LA MAGNOLIA                             '
#  'VEREDA PANTANILLO                       '
#  'EL ESMERALDAL                           '
#  'MILÁN - VALLEJUELOS                     '
#  'LOMA DE LAS BRUJAS                      '
#  'EL TRIANÓN                              '
#  'ZUÑIGA                                  '
#  'LAS ANTILLAS                            '
#  'LOMA DEL BARRO                          '
#  'SAN JOSÉ                                '
#  'EL CHINGUÍ                              '
#  'PRIMAVERA                               '
#  'LA INMACULADA                           '
#  'BOSQUES DE ZUÑIGA                       '
#  'LA PAZ                                  '
#  'SAN MARCOS                              '
#  'LA PRADERA                              '
#  'VILLAGRANDE                             '
#  'LA SEBASTIANA                           '
#  'ALTO DE MISAEL                          '
#  'LAS FLORES                              '
#  'SAN RAFAEL                              '
#  'VEREDA EL ESCOBERO                      '
#  'VEREDA EL VALLANO                       '
#  'EL PORTAL                               '
#  'LAS CASITAS                             '
#  'LOMA EL ATRAVESADO                      '
#  'EL CHOCHO                               '
#  'URIBE ANGEL                             '
#  'CENTRO                             '
#  'LAS ORQUÍDEAS                           '
#  'EL OBRERO                               '
#  'VEREDA LAS PALMAS                       '
#  'LAS VEGAS                               '
#  'VEREDA SANTA CATALINA                   '
#  'VEREDA PERICO                           '
#  'BUCAREST                                ']

# %%
# Cuantas filas y columnas tiene nuestro dataframe
INSCRITOSIE.shape
# Out:
# (120326, 24)

# %%
# libreria skimpy permite realizar estadisticos descriptivos de variables categóricas
# !pip install skimpy
from skimpy import skim

skim(INSCRITOSIE)
# Out:
# Requirement already satisfied: skimpy in /usr/local/lib/python3.11/dist-packages (0.0.18)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from skimpy) (8.1.8)
# Requirement already satisfied: ipykernel>=6.29.5 in /usr/local/lib/python3.11/dist-packages (from skimpy) (6.29.5)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.0.2)
# Requirement already satisfied: pandas-stubs>=2.2.2.240807 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.2.2.240909)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.2.3)
# Requirement already satisfied: polars>=1.17.1 in /usr/local/lib/python3.11/dist-packages (from skimpy) (1.21.0)
# Requirement already satisfied: pygments>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.18.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from skimpy) (13.9.4)
# Requirement already satisfied: typeguard>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from skimpy) (4.4.2)
# Requirement already satisfied: pyarrow>=17.0.0 in /usr/local/lib/python3.11/dist-packages (from skimpy) (18.1.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->skimpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->skimpy) (2025.2)
# Requirement already satisfied: types-pytz>=2022.1.1 in /usr/local/lib/python3.11/dist-packages (from pandas-stubs>=2.2.2.240807->skimpy) (2025.2.0.20250326)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->skimpy) (3.0.0)
# Requirement already satisfied: typing_extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from typeguard>=4.4.1->skimpy) (4.13.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (3.0.50)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (4.3.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->skimpy) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->skimpy) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.13)
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 120326 │ │ string      │ 13    │                                                          │
# │ │ Number of columns │ 18     │ │ int64       │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ datetime64  │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column     ┃ NA ┃ NA % ┃ mean     ┃ sd     ┃ p0       ┃ p25      ┃ p50      ┃ p75      ┃ p100     ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩  │
# │ │ Inscripcio │  0 │    0 │    63430 │ 178200 │      198 │    30530 │    59920 │    91020 │ 20180000 │   █    │  │
# │ │ n          │    │      │          │        │          │          │          │          │          │        │  │
# │ │ edad       │  0 │    0 │    25.64 │  21.85 │      -75 │       11 │       15 │       39 │      125 │   █▂▂  │  │
# │ │ curso      │  0 │    0 │ 20220000 │  21480 │ 20180000 │ 20210000 │ 20220000 │ 20240000 │ 20250000 │ ▅▂▄▄▅█ │  │
# │ └────────────┴────┴──────┴──────────┴────────┴──────────┴──────────┴──────────┴──────────┴──────────┴────────┘  │
# │                                                    datetime                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓  │
# │ ┃ column                 ┃ NA     ┃ NA %                    ┃ first          ┃ last           ┃ frequency    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩  │
# │ │ fecha                  │      0 │                       0 │   2018-01-17   │   2025-03-28   │ None         │  │
# │ │ fecha_nacimiento       │   3500 │       2.908764523045726 │   1900-01-01   │   2099-09-10   │ None         │  │
# │ └────────────────────────┴────────┴─────────────────────────┴────────────────┴────────────────┴──────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃       ┃          ┃          ┃          ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA    ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Servicio │     0 │        0 │ JUDO     │ TAEKWOND │ ACTIVIDA │ VOLEIBOL  │     44.2 │        32 │  3829407 │  │
# │ │          │       │          │          │ O        │ DES      │ Y VOLEY   │          │           │          │  │
# │ │          │       │          │          │          │ ACUATICA │ PLAYA     │          │           │          │  │
# │ │          │       │          │          │          │ S - ALTO │           │          │           │          │  │
# │ │          │       │          │          │          │ DE LOS   │           │          │           │          │  │
# │ │          │       │          │          │          │ SUEÑOS   │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ nom_barr │ 16064 │ 13.35039 │ MESA     │ EL       │ ALCALÁ   │ ZUÑIGA    │     39.7 │        28 │  3309307 │  │
# │ │ io       │       │ 80852018 │          │ DORADO   │          │           │          │           │          │  │
# │ │          │       │       69 │          │          │          │           │          │           │          │  │
# │ │ Género   │     0 │        0 │ FEMENINO │ NO       │ FEMENINO │ NO        │     8.46 │         1 │   121129 │  │
# │ │          │       │          │          │ REGISTRA │          │ REGISTRA  │          │           │          │  │
# │ │ etnia    │ 11637 │ 9.671226 │ Rom      │ Mestiza  │ Afrocolo │ Rom       │     42.2 │        33 │  3912613 │  │
# │ │          │       │ 50133803 │          │          │ mbiana   │           │          │           │          │  │
# │ │          │       │        1 │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ Poblacio │ 11651 │ 9.682861 │ Migrante │ Ninguna  │ Campesin │ Víctima   │     32.8 │        16 │  1921237 │  │
# │ │ n        │       │ 55943021 │          │ de las   │ o        │ del       │          │           │          │  │
# │ │          │       │        5 │          │ anterior │          │ conflicto │          │           │          │  │
# │ │          │       │          │          │ es       │          │ armado    │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ Escenari │     0 │        0 │ SALON DE │ SALON DE │  CEC     │ ZUÑIGA    │       50 │        33 │  3995363 │  │
# │ │ o        │       │          │ GIMNASIA │ GIMNASIA │ CASA     │           │          │           │          │  │
# │ │          │       │          │ INFANTIL │ INFANTIL │ LINARES  │           │          │           │          │  │
# │ │          │       │          │ POLIDEPO │ POLIDEPO │          │           │          │           │          │  │
# │ │          │       │          │ RTIVO    │ RTIVO    │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ instruct │     0 │        0 │ MARIA    │ _x0002_B │   MARIA  │ _x0002_BE │       80 │        59 │  7063329 │  │
# │ │ or       │       │          │ FERNANDA │ ETSY     │ CAROLINA │ TSY       │          │           │          │  │
# │ │          │       │          │ OSPINA   │ JULIETH  │ MORALES- │ JULIETH   │          │           │          │  │
# │ │          │       │          │          │ MURIEL   │ MARIBEL  │ MURIEL    │          │           │          │  │
# │ │          │       │          │          │ MUNERA   │ SANCHEZ  │ MUNERA    │          │           │          │  │
# │ │ eps      │ 14885 │ 12.37055 │ SURA     │ SURA     │          │ VIVE      │       30 │        20 │  2354383 │  │
# │ │          │       │ 99787244 │          │          │          │ PROTECCIÓ │          │           │          │  │
# │ │          │       │       65 │          │          │          │ N         │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ cod_ciu  │ 15059 │ 12.51516 │ ENVIGADO │ ENVIGADO │          │ ÁNDES     │       35 │        25 │  2956125 │  │
# │ │          │       │ 71292987 │          │          │          │           │          │           │          │  │
# │ │          │       │       39 │          │          │          │           │          │           │          │  │
# │ │ tipo_doc │ 14584 │ 12.12040 │ Registro │ Registro │ Cédula   │ Tipo      │       40 │        21 │  2493056 │  │
# │ │ umento   │       │ 62297425 │ Civil    │ Civil    │ de       │ documento │          │           │          │  │
# │ │          │       │       33 │          │          │ Ciudadan │ Extranjer │          │           │          │  │
# │ │          │       │          │          │          │ ía       │ o         │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ rh       │ 12343 │ 10.25796 │ A+       │ A+       │          │ o-        │        5 │       3.6 │   435949 │  │
# │ │          │       │ 58594152 │          │          │          │           │          │           │          │  │
# │ │          │       │       56 │          │          │          │           │          │           │          │  │
# │ │ diversid │   858 │ 0.713062 │ No       │ Bisexual │ Bisexual │ Trans     │     10.6 │         2 │   244056 │  │
# │ │ ad       │       │ 84593520 │ Aplica   │          │          │           │          │           │          │  │
# │ │          │       │       93 │          │          │          │           │          │           │          │  │
# │ │ Població │     0 │        0 │ NO       │ NO       │ ALTO     │ VICTIMA   │       50 │        45 │  5465792 │  │
# │ │ n        │       │          │ APLICA   │ APLICA   │ RENDIMIE │           │          │           │          │  │
# │ │          │       │          │          │          │ NTO      │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ └──────────┴───────┴──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
#muestra los primeros 20 registros
INSCRITOSIE.head(20)
# Out:
#         fecha  Inscripcion                                           Servicio  \
# 0  2018-01-17        89536                                  GIMNASIA INFANTIL
# 1  2018-01-17        89528                                  GIMNASIA INFANTIL
# 2  2018-01-17        89535                                  GIMNASIA INFANTIL
# 3  2018-01-17        89531                                           NATACIÓN
# 4  2018-01-17        89533                                  GIMNASIA INFANTIL
# 5  2018-01-17        89530                                  GIMNASIA INFANTIL
# 6  2018-01-17        89521                                           NATACIÓN
# 7  2018-01-17        89525                                           NATACIÓN
# 8  2018-01-17        89518                                           NATACIÓN
# 9  2018-01-17        89532                                  GIMNASIA INFANTIL
# 10 2018-01-17        89537                                  GIMNASIA INFANTIL
# 11 2018-01-17        89522                                           NATACIÓN
# 12 2018-01-18        89683  TAEKWONDO                                     ...
# 13 2018-01-18        89644                                           NATACIÓN
# 14 2018-01-18        89651                                           NATACIÓN
# 15 2018-01-18        89541                                           NATACIÓN
# 16 2018-01-18        89679                                  GIMNASIA INFANTIL
# 17 2018-01-18        89662                                           NATACIÓN
# 18 2018-01-18        89663                                           NATACIÓN
# 19 2018-01-18        89666                                           NATACIÓN
#
#                                                 Nivel  \
# 0   INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1   PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2   NIVEL 2 (6-15AÑOS)                            ...
# 3   CALAMARES                                     ...
# 4   INICIACIÓN 2 (8-12)                           ...
# 5   FORMATIVA 3-4 AÑOS MIXTO                      ...
# 6   I (6-8) AÑOS                                  ...
# 7   III ADULTOS                                   ...
# 8   VII ADULTOS                                   ...
# 9   INICIACIÓN 2 (8-12)                           ...
# 10  INICIACIÓN 2 (8-12)                           ...
# 11  IV NIÑOS                                      ...
# 12  SELECCIÓN A                                   ...
# 13  CARACOLES                                     ...
# 14  VII NIÑOS                                     ...
# 15  BEBES CON ACUDIENTE (36 A 48 MESES)           ...
# 16  INICIACIÓN 1 (7-10 AÑOS)                      ...
# 17  VI NIÑOS                                      ...
# 18  V ADULTOS                                     ...
# 19  CARACOLES                                     ...
#
#                                   nom_barrio  edad     Género  \
# 0                                        NaN    15   FEMENINO
# 1   EL DORADO                                   12   FEMENINO
# 2                                        NaN    16   FEMENINO
# 3                                        NaN     0   FEMENINO
# 4                                        NaN    15   FEMENINO
# 5   NO APLICA                                    9  MASCULINO
# 6                                        NaN    15   FEMENINO
# 7                                        NaN    20  MASCULINO
# 8                                        NaN    22  MASCULINO
# 9                                        NaN    12  MASCULINO
# 10                                       NaN     0   FEMENINO
# 11  OTRO                                        19  MASCULINO
# 12  JARDINES                                    28   FEMENINO
# 13                                       NaN    12   FEMENINO
# 14                                       NaN    14  MASCULINO
# 15                                       NaN    11  MASCULINO
# 16                                       NaN    14   FEMENINO
# 17  EL SALADO                                   13  MASCULINO
# 18                                       NaN    35   FEMENINO
# 19                                       NaN    11  MASCULINO
#
#                                                 etnia  \
# 0                                                 NaN
# 1   Mestiza                                       ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Mestiza                                       ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Mestiza                                       ...
# 10                                                NaN
# 11  Otro                                          ...
# 12  Mestiza                                       ...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  Mestiza                                       ...
# 18  Mestiza                                       ...
# 19                                                NaN
#
#                                             Poblacion  \
# 0                                                 NaN
# 1                                           No Aplica
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                           No Aplica
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Ninguna de las anteriores                     ...
# 10                                                NaN
# 11  Ninguna de las anteriores                     ...
# 12  Ninguna de las anteriores                     ...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                          No Aplica
# 18                                          No Aplica
# 19                                                NaN
#
#                                             Escenario  ...  \
# 0   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3   PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 5   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 6   PISCINA POLIDEPORTIVO SUR                     ...  ...
# 7   PISCINA POLIDEPORTIVO SUR                     ...  ...
# 8   PISCINA POLIDEPORTIVO SUR                     ...  ...
# 9   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 10  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 11  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 12  DOJAN TAEKWONDO                               ...  ...
# 13  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 14  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 15  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 16  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 17  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 18  PISCINA POLIDEPORTIVO SUR                     ...  ...
# 19  PISCINA POLIDEPORTIVO SUR                     ...  ...
#
#                                eps  estrato  \
# 0                              NaN      NaN
# 1   SURA                                  3
# 2                              NaN      NaN
# 3                              NaN      NaN
# 4                              NaN      NaN
# 5   SURA                                  3
# 6                              NaN      NaN
# 7                              NaN      NaN
# 8                              NaN      NaN
# 9                              NaN        4
# 10                             NaN      NaN
# 11  REGIMEN ESPECIAL                      3
# 12  SURA EPS                              5
# 13                             NaN      NaN
# 14                             NaN      NaN
# 15                             NaN      NaN
# 16                             NaN      NaN
# 17  SURA EPS                              2
# 18                             NaN        2
# 19                             NaN      NaN
#
#                                 cod_ciu  \
# 0                                   NaN
# 1   ENVIGADO
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5   SABANETA
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11  ENVIGADO
# 12  ENVIGADO
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17  ENVIGADO
# 18                                  NaN
# 19                                  NaN
#
#                               tipo_documento  \
# 0                                        NaN
# 1   Registro Civil
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5   Registro Civil
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11  Tarjeta de Identidad
# 12  Cédula de Ciudadanía
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17  Tarjeta de Identidad
# 18                                       NaN
# 19                                       NaN
#
#                                   nacimiento     rh  \
# 0                                        NaN    NaN
# 1   ENVIGADO                                  A+
# 2                                        NaN    NaN
# 3                                        NaN    NaN
# 4                                        NaN    NaN
# 5   ITAGUI                                    A+
# 6                                        NaN    NaN
# 7                                        NaN    NaN
# 8                                        NaN    NaN
# 9                                        NaN  O-
# 10                                       NaN    NaN
# 11                                       NaN  O+
# 12  MEDELLIN                                  A+
# 13                                       NaN    NaN
# 14                                       NaN    NaN
# 15                                       NaN    NaN
# 16                                       NaN    NaN
# 17                                       NaN  O-
# 18                                       NaN  A-
# 19                                       NaN    NaN
#
#                                          nacionalidad  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Colombia                                      ...
# 12  Colombia                                      ...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  COLOMBIA                                      ...
# 18                                                NaN
# 19                                                NaN
#
#                                  escolaridad diversidad  \
# 0                                        NaN  No Aplica
# 1   PREESCOLAR                                No Aplica
# 2                                        NaN  No Aplica
# 3                                        NaN  No Aplica
# 4                                        NaN  No Aplica
# 5   NINGUNO                                   No Aplica
# 6                                        NaN  No Aplica
# 7                                        NaN  No Aplica
# 8                                        NaN  No Aplica
# 9   BÁSICA PRIMARIA                           No Aplica
# 10                                       NaN  No Aplica
# 11  EDUCACIÓN MEDIA ( 10° Y 11°)              No Aplica
# 12  PROFESIONAL                               No Aplica
# 13                                       NaN  No Aplica
# 14                                       NaN  No Aplica
# 15                                       NaN  No Aplica
# 16                                       NaN  No Aplica
# 17  BÁSICA SECUNDARIA                         No Aplica
# 18  TECNICA                                   No Aplica
# 19                                       NaN  No Aplica
#
#                                             Población
# 0   NO APLICA                                     ...
# 1   NO APLICA                                     ...
# 2   NO APLICA                                     ...
# 3   NO APLICA                                     ...
# 4   NO APLICA                                     ...
# 5   NO APLICA                                     ...
# 6   NO APLICA                                     ...
# 7   NO APLICA                                     ...
# 8   INCAPACIDAD DE PAGO Y/O CONVENIO 100%         ...
# 9   NO APLICA                                     ...
# 10  NO APLICA                                     ...
# 11  INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 12  NO APLICA                                     ...
# 13  NO APLICA                                     ...
# 14  DESPLAZADO                                    ...
# 15  NO APLICA                                     ...
# 16  NO APLICA                                     ...
# 17  DESPLAZADO                                    ...
# 18  DESPLAZADO                                    ...
# 19  NO APLICA                                     ...
#
# [20 rows x 24 columns]

# %%
## comando TAIL para visualizar ultimos registros
INSCRITOSIE.tail(20)
# Out:
#             fecha  Inscripcion  \
# 120306 2025-03-28        94243
# 120307 2025-03-28        94232
# 120308 2025-03-28        94242
# 120309 2025-03-28        94251
# 120310 2025-03-28        65201
# 120311 2025-03-28        94248
# 120312 2025-03-28        94246
# 120313 2025-03-28        94250
# 120314 2025-03-28        94245
# 120315 2025-03-28        94238
# 120316 2025-03-28        94233
# 120317 2025-03-28        94234
# 120318 2025-03-28        94239
# 120319 2025-03-28        94237
# 120320 2025-03-28        94249
# 120321 2025-03-28        94235
# 120322 2025-03-28        94240
# 120323 2025-03-28        94244
# 120324 2025-03-28        94247
# 120325 2025-03-28        94241
#
#                                                  Servicio  \
# 120306  FUTSALA-FUTBOL DE SALON                       ...
# 120307  FUTSALA-FUTBOL DE SALON                       ...
# 120308  FUTSALA-FUTBOL DE SALON                       ...
# 120309  FUTSALA-FUTBOL DE SALON                       ...
# 120310  CENTRO DE INICIACIÓN Y FORMACIÓN DEPORTIVA    ...
# 120311  FUTSALA-FUTBOL DE SALON                       ...
# 120312  FUTSALA-FUTBOL DE SALON                       ...
# 120313  FUTSALA-FUTBOL DE SALON                       ...
# 120314  FUTSALA-FUTBOL DE SALON                       ...
# 120315  FUTSALA-FUTBOL DE SALON                       ...
# 120316  FUTSALA-FUTBOL DE SALON                       ...
# 120317  FUTSALA-FUTBOL DE SALON                       ...
# 120318  FUTSALA-FUTBOL DE SALON                       ...
# 120319  FUTSALA-FUTBOL DE SALON                       ...
# 120320  FUTSALA-FUTBOL DE SALON                       ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 120306  SEMILLERO                                     ...
# 120307  JUNIOR 14/15                                  ...
# 120308  SEMILLERO                                     ...
# 120309  INFANTIL 10/12                                ...
# 120310  INSCRIPCIÓN NIÑOS (4 - 5 AÑOS) Fase 1         ...
# 120311  INFANTIL 10/12                                ...
# 120312  INFANTIL 10/12                                ...
# 120313  INFANTIL 10/12                                ...
# 120314  INFANTIL 10/12                                ...
# 120315  JUNIOR 14/15                                  ...
# 120316  JUNIOR 14/15                                  ...
# 120317  JUNIOR 14/15                                  ...
# 120318  JUNIOR 14/15                                  ...
# 120319  JUNIOR 14/15                                  ...
# 120320  INFANTIL 10/12                                ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                       nom_barrio  edad     Género  \
# 120306  EL DORADO                                    5   FEMENINO
# 120307  SAN JOSÉ                                    14  MASCULINO
# 120308  LA MINA                                      8  MASCULINO
# 120309  LA SEBASTIANA                               11  MASCULINO
# 120310  SAN JOSÉ                                     4  MASCULINO
# 120311         MESA                                 10  MASCULINO
# 120312  EL SALADO                                    1  MASCULINO
# 120313  LA SEBASTIANA                               10  MASCULINO
# 120314         MESA                                 11  MASCULINO
# 120315  LA SEBASTIANA                               15  MASCULINO
# 120316  SAN RAFAEL                                  14  MASCULINO
# 120317  LA SEBASTIANA                               15  MASCULINO
# 120318  OTRO                                        14  MASCULINO
# 120319                                       NaN    14  MASCULINO
# 120320  SAN JOSÉ                                    10  MASCULINO
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     etnia  \
# 120306                                  No desea informar
# 120307  Mestiza                                       ...
# 120308                                No se autorreconoce
# 120309  Mestiza                                       ...
# 120310  Blanco                                        ...
# 120311  Raizal                                        ...
# 120312                     Afrocolombiana
# 120313  Mestiza                                       ...
# 120314  Mestiza                                       ...
# 120315                     Afrocolombiana
# 120316  Mestiza                                       ...
# 120317                                No se autorreconoce
# 120318  Blanco                                        ...
# 120319                                                NaN
# 120320  Mestiza                                       ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 120306  Desplazado                                    ...
# 120307                                          No Aplica
# 120308  Desplazado                                    ...
# 120309  Ninguna de las anteriores                     ...
# 120310  Ninguna de las anteriores                     ...
# 120311                                          No Aplica
# 120312  Ninguna de las anteriores                     ...
# 120313  Ninguna de las anteriores                     ...
# 120314                                          No Aplica
# 120315  Ninguna de las anteriores                     ...
# 120316  Desplazado                                    ...
# 120317  Ninguna de las anteriores                     ...
# 120318                                          Campesino
# 120319                                                NaN
# 120320  Ninguna de las anteriores                     ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 120306  PLACA LA MERCED                               ...  ...
# 120307  PLACA LA MERCED                               ...  ...
# 120308  PLACA LA MERCED                               ...  ...
# 120309  PLACA LA MERCED                               ...  ...
# 120310  PARQUE RECREATIVO                             ...  ...
# 120311  PLACA LA MERCED                               ...  ...
# 120312  PLACA LA MERCED                               ...  ...
# 120313  PLACA LA MERCED                               ...  ...
# 120314  PLACA LA MERCED                               ...  ...
# 120315  PLACA LA MERCED                               ...  ...
# 120316  PLACA LA MERCED                               ...  ...
# 120317  PLACA LA MERCED                               ...  ...
# 120318  PLACA LA MERCED                               ...  ...
# 120319  PLACA LA MERCED                               ...  ...
# 120320  PLACA LA MERCED                               ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    eps  estrato  \
# 120306  SALUD TOTAL S.A. EPS                  3
# 120307  EPS SURAMERICANA                      2
# 120308  SAVIA SALUD EPS                       3
# 120309  SURA EPS                              3
# 120310  NUEVA EPS S.A.                        2
# 120311  SURA EPS                              3
# 120312  SALUD TOTAL S.A. EPS                  2
# 120313  SURA EPS                              2
# 120314  SANITAS S.A. E.P.S.                   3
# 120315  COMFAMA                               2
# 120316  SALUD TOTAL S.A. EPS                  2
# 120317  SURA EPS                              2
# 120318  COMFAMA                               2
# 120319                             NaN      NaN
# 120320  SURA EPS                              3
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                                     cod_ciu  \
# 120306  ENVIGADO
# 120307  ENVIGADO
# 120308  ENVIGADO
# 120309  ENVIGADO
# 120310  ENVIGADO
# 120311  ENVIGADO
# 120312  ENVIGADO
# 120313  ENVIGADO
# 120314  ENVIGADO
# 120315  ENVIGADO
# 120316  ENVIGADO
# 120317  ENVIGADO
# 120318  ITAGUÍ
# 120319                                  NaN
# 120320  ENVIGADO
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   tipo_documento  \
# 120306  Registro Civil
# 120307  Tarjeta de Identidad
# 120308  Tarjeta de Identidad
# 120309  Tarjeta de Identidad
# 120310  Registro Civil
# 120311  Tarjeta de Identidad
# 120312  Tarjeta de Identidad
# 120313  Tarjeta de Identidad
# 120314  Tarjeta de Identidad
# 120315  Tarjeta de Identidad
# 120316  Tarjeta de Identidad
# 120317  Tarjeta de Identidad
# 120318  Tarjeta de Identidad
# 120319                                       NaN
# 120320  Tarjeta de Identidad
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       nacimiento     rh  \
# 120306                                       NaN  O+
# 120307                                       NaN  A+
# 120308                                       NaN  B+
# 120309                                       NaN  A+
# 120310                                       NaN  A-
# 120311                                       NaN  O+
# 120312                                       NaN  O+
# 120313                                       NaN  O-
# 120314  MEDELLIN                                  O+
# 120315                                       NaN  O+
# 120316                                       NaN  O+
# 120317                                       NaN  O-
# 120318                                       NaN  O+
# 120319                                       NaN    NaN
# 120320  ENVIGADO                                  A+
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              nacionalidad  \
# 120306  COLOMBIA                                      ...
# 120307  COLOMBIA                                      ...
# 120308  COLOMBIA                                      ...
# 120309  COLOMBIA                                      ...
# 120310  COLOMBIA                                      ...
# 120311  COLOMBIA                                      ...
# 120312  COLOMBIA                                      ...
# 120313  COLOMBIA                                      ...
# 120314  COLOMBIA                                      ...
# 120315  COLOMBIA                                      ...
# 120316  COLOMBIA                                      ...
# 120317  COLOMBIA                                      ...
# 120318  COLOMBIA                                      ...
# 120319                                                NaN
# 120320  COLOMBIA                                      ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      escolaridad         diversidad  \
# 120306  BÁSICA PRIMARIA                           No desea informar
# 120307  BÁSICA PRIMARIA                                Heterosexual
# 120308  BÁSICA PRIMARIA                                Heterosexual
# 120309  EDUCACIÓN MEDIA                                Heterosexual
# 120310  NINGUNO                                   No desea informar
# 120311  PREESCOLAR                                        No Aplica
# 120312  BÁSICA PRIMARIA                           No desea informar
# 120313  BÁSICA PRIMARIA                                Heterosexual
# 120314  BÁSICA PRIMARIA                                   No Aplica
# 120315  BÁSICA SECUNDARIA                          No se identifica
# 120316  BÁSICA SECUNDARIA                              Heterosexual
# 120317  BÁSICA SECUNDARIA                              Heterosexual
# 120318  BÁSICA SECUNDARIA                              Heterosexual
# 120319                                       NaN          No Aplica
# 120320  BÁSICA PRIMARIA                           No desea informar
# 120321  BÁSICA SECUNDARIA                          No se identifica
# 120322  BÁSICA PRIMARIA                                Heterosexual
# 120323  BÁSICA PRIMARIA                                Heterosexual
# 120324  BÁSICA SECUNDARIA                                 No Aplica
# 120325  BÁSICA PRIMARIA                                Heterosexual
#
#                                                 Población
# 120306  NO APLICA                                     ...
# 120307  NO APLICA                                     ...
# 120308  NO APLICA                                     ...
# 120309  NO APLICA                                     ...
# 120310  CIFD                                          ...
# 120311  NO APLICA                                     ...
# 120312  NO APLICA                                     ...
# 120313  NO APLICA                                     ...
# 120314  NO APLICA                                     ...
# 120315  NO APLICA                                     ...
# 120316  NO APLICA                                     ...
# 120317  NO APLICA                                     ...
# 120318  NO APLICA                                     ...
# 120319  NO APLICA                                     ...
# 120320  NO APLICA                                     ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [20 rows x 24 columns]

# %% [markdown]
# **Limpieza de datos**

# %%
##Renombramos las columnas
INSCRITOSIE.rename(columns={"fecha": "fecha_inscripción"})
# Out:
#        fecha_inscripción  Inscripcion  \
# 0             2018-01-17        89536
# 1             2018-01-17        89528
# 2             2018-01-17        89535
# 3             2018-01-17        89531
# 4             2018-01-17        89533
# ...                  ...          ...
# 120321        2025-03-28        94235
# 120322        2025-03-28        94240
# 120323        2025-03-28        94244
# 120324        2025-03-28        94247
# 120325        2025-03-28        94241
#
#                                                  Servicio  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                       nom_barrio  edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                                     cod_ciu  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      escolaridad        diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
##Renombramos las columnas

INSCRITOSIE = INSCRITOSIE.rename(columns={"Inscripcion": "Nro_inscripcion"})
INSCRITOSIE = INSCRITOSIE.rename(columns={"nom_barrio": "Barrio"})
INSCRITOSIE = INSCRITOSIE.rename(columns={"Servicio": "Disciplina"})
INSCRITOSIE = INSCRITOSIE.rename(columns={"cod_ciu": "Municipio_residencia"})
INSCRITOSIE
# Out:
#             fecha  Nro_inscripcion  \
# 0      2018-01-17            89536
# 1      2018-01-17            89528
# 2      2018-01-17            89535
# 3      2018-01-17            89531
# 4      2018-01-17            89533
# ...           ...              ...
# 120321 2025-03-28            94235
# 120322 2025-03-28            94240
# 120323 2025-03-28            94244
# 120324 2025-03-28            94247
# 120325 2025-03-28            94241
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                           Barrio  edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      escolaridad        diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
# Convertir la columna 'Disciplina' a texto en mayúsculas
INSCRITOSIE['Disciplina'] = INSCRITOSIE['Disciplina'].str.upper()

# %%
## cambio de nombre de columna
INSCRITOSIE.rename(columns={'fecha': 'Fecha'}, inplace=True)
INSCRITOSIE.rename(columns={'edad': 'Edad'}, inplace=True)
INSCRITOSIE.rename(columns={'etnia': 'Etnia'}, inplace=True)
INSCRITOSIE.rename(columns={'eps': 'Eps'}, inplace=True)
INSCRITOSIE.rename(columns={'estrato': 'Estrato'}, inplace=True)
INSCRITOSIE.rename(columns={'tipo_documento': 'Tipo documento'}, inplace=True)
INSCRITOSIE.rename(columns={'nacimiento': 'Nacimiento'}, inplace=True)
INSCRITOSIE.rename(columns={'rh': 'Rh'}, inplace=True)
INSCRITOSIE.rename(columns={'nacionalidad': 'Nacionalidad'}, inplace=True)
INSCRITOSIE.rename(columns={'escolaridad': 'Escolaridad'}, inplace=True)
INSCRITOSIE.rename(columns={'diversidad': 'Diversidad'}, inplace=True)
INSCRITOSIE.rename(columns={'instructor': 'Instructor'}, inplace=True)
INSCRITOSIE.rename(columns={'curso': 'Curso'}, inplace=True)
INSCRITOSIE.rename(columns={'zona': 'Zona'}, inplace=True)
INSCRITOSIE.rename(columns={'fecha_nacimiento': 'Fecha nacimiento'}, inplace=True)

# %%
INSCRITOSIE
# Out:
#             Fecha  Nro_inscripcion  \
# 0      2018-01-17            89536
# 1      2018-01-17            89528
# 2      2018-01-17            89535
# 3      2018-01-17            89531
# 4      2018-01-17            89533
# ...           ...              ...
# 120321 2025-03-28            94235
# 120322 2025-03-28            94240
# 120323 2025-03-28            94244
# 120324 2025-03-28            94247
# 120325 2025-03-28            94241
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                           Barrio  Edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     Etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    Eps  Estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   Tipo documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       Nacimiento     Rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              Nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      Escolaridad        Diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
## transformar el tipo de dato en algunas columnas.

INSCRITOSIE = INSCRITOSIE.astype({'Nro_inscripcion': 'int32'})

INSCRITOSIE['Nivel'] = INSCRITOSIE['Nivel'].astype('category')

INSCRITOSIE = INSCRITOSIE.astype({'Disciplina': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Barrio': 'category'})

# Convertir la columna 'Edad' a numérica, manejando errores
INSCRITOSIE['Edad'] = pd.to_numeric(INSCRITOSIE['Edad'], errors='coerce') #This line handles the error.

# Ahora conviértalo a int32, rellenando los NaN con un valor adecuado (por ejemplo, 0) si es necesario
INSCRITOSIE['Edad'] = INSCRITOSIE['Edad'].fillna(0).astype('int32') #Si se introdujeron valores nulos mediante to_numeric, rellénelos y luego conviértalos a int.

INSCRITOSIE = INSCRITOSIE.astype({'Género': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Etnia': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Poblacion': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Escenario': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Instructor': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Curso': 'int32'})

INSCRITOSIE = INSCRITOSIE.astype({'Zona': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Eps': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Estrato': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Municipio_residencia': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Tipo documento': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Nacimiento': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Rh': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Nacionalidad': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Escolaridad': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Diversidad': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Población': 'category'})

# %%
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120326 entries, 0 to 120325
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Fecha                 120326 non-null  datetime64[ns]
#  1   Nro_inscripcion       120326 non-null  int32
#  2   Disciplina            120326 non-null  category
#  3   Nivel                 120326 non-null  category
#  4   Barrio                104262 non-null  category
#  5   Edad                  120326 non-null  int32
#  6   Género                120326 non-null  category
#  7   Etnia                 108689 non-null  category
#  8   Poblacion             108675 non-null  category
#  9   Escenario             120326 non-null  category
#  10  Instructor            120326 non-null  category
#  11  Curso                 120326 non-null  int32
#  12  Zona                  99596 non-null   category
#  13  Fecha nacimiento      116826 non-null  datetime64[ns]
#  14  Eps                   105441 non-null  category
#  15  Estrato               107761 non-null  category
#  16  Municipio_residencia  105267 non-null  category
#  17  Tipo documento        105742 non-null  category
#  18  Nacimiento            17915 non-null   category
#  19  Rh                    107983 non-null  category
#  20  Nacionalidad          99124 non-null   category
#  21  Escolaridad           107267 non-null  category
#  22  Diversidad            119468 non-null  category
#  23  Población             120326 non-null  category
# dtypes: category(19), datetime64[ns](2), int32(3)
# memory usage: 6.2 MB

# %%
## creo una copia del DF original, para posteriormente modificarlo
INSCRITOSIE_2 = INSCRITOSIE

# %%
# El metodo replace Identifica el valor a buscar y luego reemplaza en todos los campos con el valor deseado.
INSCRITOSIE = INSCRITOSIE.replace("", None)
INSCRITOSIE
# Out:
#             Fecha  Nro_inscripcion  \
# 0      2018-01-17            89536
# 1      2018-01-17            89528
# 2      2018-01-17            89535
# 3      2018-01-17            89531
# 4      2018-01-17            89533
# ...           ...              ...
# 120321 2025-03-28            94235
# 120322 2025-03-28            94240
# 120323 2025-03-28            94244
# 120324 2025-03-28            94247
# 120325 2025-03-28            94241
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                           Barrio  Edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     Etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    Eps  Estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   Tipo documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       Nacimiento     Rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              Nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      Escolaridad        Diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
# Limpiamos columnas de texto eliminando espacios innecesarios y convertimos primeras letras de una palabra a mayúsculas
def limpiar_texto(texto):
    if isinstance(texto, str):  # Verificamos que el valor sea string
        return ' '.join(texto.strip().title().split())  # Elimina espacios innecesarios y convierte el formato
    return texto  # Si no es texto, se devuelve el valor original sin cambios

# Lista de columnas de texto que se van a limpiar
columnas_texto = ['Fecha', 'Nro_inscripcion', 'Disciplina', 'Nivel', 'Barrio', 'Edad',
                   'Género', 'Etnia', 'Poblacion', 'Escenario', 'Instructor',
                   'Curso', 'Zona', 'Fecha nacimiento', 'Eps',
                   'Estrato', 'Municipio_residencia', 'Tipo documento','Nacimiento', 'Rh','Nacionalidad', 'Escolaridad','Diversidad','Población' ]

# Aplicación de la función de limpieza a las columnas de texto
INSCRITOSIE[columnas_texto] = INSCRITOSIE[columnas_texto].applymap(limpiar_texto)
# Out:
# <ipython-input-286-ceb21aa89300>:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   INSCRITOSIE[columnas_texto] = INSCRITOSIE[columnas_texto].applymap(limpiar_texto)

# %%
# Reemplazar los valores nulos por None y No APLICA por OTRO
INSCRITOSIE['Barrio'] = INSCRITOSIE['Barrio'].replace({'NULL': None})
INSCRITOSIE['Barrio'] = INSCRITOSIE['Barrio'].replace({'No Aplica': 'Otro'})
# Out:
# <ipython-input-260-0be1b095bd7b>:3: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   INSCRITOSIE['Barrio'] = INSCRITOSIE['Barrio'].replace({'No Aplica': 'Otro'})

# %%
# verificar valores únicos en Barrio
print(INSCRITOSIE['Barrio'].unique())
# Out:
# [NaN, 'El Dorado', 'Otro', 'Jardines', 'El Salado', ..., 'Vereda Las Palmas', 'Las Vegas', 'Vereda Santa Catalina', 'Vereda Perico', 'Bucarest']
# Length: 47
# Categories (46, object): ['Alcalá', 'Alto De Misael', 'Bosques De Zuñiga', 'Bucarest', ...,
#                           'Vereda Perico', 'Vereda Santa Catalina', 'Villagrande', 'Zuñiga']

# %%
## # verificar valores únicos en Disciplina
print(INSCRITOSIE['Disciplina'].unique())
# Out:
# ['Gimnasia Infantil', 'Natación', 'Taekwondo', 'Tenis De Campo', 'Escuela De Futbol De Interes Social- Efisae', ..., 'Ultimate', 'Deporte Adaptado', 'Tejo', 'Programa Sin Barreras', 'Actividades Sede Palmeras Deport. Y Activ Fis...]
# Length: 53
# Categories (53, object): ['Actividades Acuaticas - Alto De Los Sueños', 'Actividades Sede Palmeras Deport. Y Activ Fis...,
#                           'Actividades Sub Acuaticas', 'Ajedrez', ..., 'Torneos', 'Trepadores A La Catedral',
#                           'Ultimate', 'Voleibol Y Voley Playa']

# %%
## Esta opción te mostrará los valores únicos junto con su frecuencia, ordenados de mayor a menor:
## Usar prettytable para una visualización tabular
from prettytable import PrettyTable

# Contar los valores únicos y ordenarlos
disciplina_counts = INSCRITOSIE['Disciplina'].value_counts().sort_values(ascending=False)

# Crear una tabla
table = PrettyTable()
table.field_names = ["Disciplina", "Frecuencia"]

# Agregar los valores únicos a la tabla
for disciplina, frecuencia in disciplina_counts.items():
    table.add_row([disciplina, frecuencia])

# Imprimir la tabla
print(table)
# Out:
# +--------------------------------------------------+------------+
# |                    Disciplina                    | Frecuencia |
# +--------------------------------------------------+------------+
# |                    Pp Zona 7                     |   13763    |
# |                    Pp Zona 6                     |   10188    |
# |   Escuela De Futbol De Interes Social- Efisae    |    8702    |
# |                     Natación                     |    8510    |
# |                    Pp Zona 9                     |    6918    |
# |                    Pp Zona 8                     |    6815    |
# |                  Tenis De Campo                  |    6719    |
# |                    Pp Zona 5                     |    5506    |
# |                Gimnasia Infantil                 |    5011    |
# |    Actividades Acuaticas - Alto De Los Sueños    |    4741    |
# |              Voleibol Y Voley Playa              |    4129    |
# |                    Pp Zona 3                     |    3982    |
# |                    Pp Zona 2                     |    3489    |
# |               Natación Las Cometas               |    3171    |
# |                    Pp Zona 13                    |    3037    |
# |                    Taekwondo                     |    2717    |
# |                    Pp Zona 12                    |    2646    |
# |    Centro De Iniciación Y Formación Deportiva    |    2583    |
# |                    Pp Zona 4                     |    2218    |
# |       Tenis De Campo - Alto De Los Sueños        |    2102    |
# |                    Baloncesto                    |    1856    |
# |                    Pp Zona 11                    |    1713    |
# |                    Atletismo                     |    1016    |
# |                 Natación Palmas                  |    958     |
# |         Otros Ingresos Parque Recreativo         |    956     |
# |                    Pp Zona 10                    |    943     |
# |                     Sóftbol                      |    635     |
# |                 Deporte Adaptado                 |    605     |
# |                      Boxeo                       |    484     |
# |              Programa Sin Barreras               |    452     |
# |             Futsala-Futbol De Salon              |    440     |
# |                     Beisbol                      |    400     |
# |                  Tenis De Mesa                   |    381     |
# |                    Bicicross                     |    374     |
# |                     Arquería                     |    299     |
# |             Halterofilia (Lev.Pesas)             |    277     |
# |                      Rugby                       |    252     |
# |                    Badminton                     |    237     |
# |                     Ajedrez                      |    198     |
# | Actividades Sede Palmeras Deport. Y Activ Fisica |    151     |
# |            Actividades Sub Acuaticas             |    129     |
# |                 Futbol Femenino                  |    119     |
# |                     Ciclismo                     |    117     |
# |                     Torneos                      |    107     |
# |                       Judo                       |     55     |
# |                      Lucha                       |     49     |
# |                Nuevas Tendencias                 |     46     |
# |                       Tejo                       |     43     |
# |                      Karate                      |     42     |
# |                 Futbol Masculino                 |     26     |
# |                     Ultimate                     |     14     |
# |               Apoyo A Deportistas                |     3      |
# |             Trepadores A La Catedral             |     2      |
# +--------------------------------------------------+------------+

# %%
## Usa matplotlib para graficar.
import pandas as pd
import matplotlib.pyplot as plt

# Contar y ordenar las disciplinas
disciplina_counts = INSCRITOSIE['Disciplina'].value_counts().sort_values(ascending=False)

# Crear un gráfico de barras horizontales
plt.figure(figsize=(12, 8))
disciplina_counts.plot(kind='barh', color='lightgreen')
plt.title('Frecuencia de Disciplinas (Ordenado de Mayor a Menor)', fontsize=16)
plt.xlabel('Frecuencia', fontsize=14)
plt.ylabel('Disciplina', fontsize=14)
plt.tight_layout()  # Ajustar el layout
plt.show()

# %%
## se utiliza para eliminar la columna 'nacimiento' del DataFrame INSCRITOSIE de manera permanente.
##INSCRITOSIE.dop(columns=['nacimiento'],inplace=true)
##INSCRITOSE

# %%
## buscar duplicados en el dataframe
INSCRITOSIE.duplicated().sum()
# Out:
# np.int64(1)

# %%
import numpy as np

# Verificar si la edad es menor o igual a cero y reemplazarla por NaN
INSCRITOSIE.loc[INSCRITOSIE['Edad'] <= 0, 'Edad'] = np.nan

# %%
# Verificar si la edad es mayor a 100 años y reemplazarla por NaN
INSCRITOSIE.loc[INSCRITOSIE['Edad'] > 100, 'Edad'] = np.nan

# %%
print(INSCRITOSIE['Edad'].isna().sum())  # Para contar cuántos NaN hay en la columna 'edad'
# Out:
# 3511

# %%
## Edad promedio de inscritos en la base de datos
INSCRITOSIE['Edad'].mean()
# Out:
# np.float64(26.408911526773103)

# %%
## Desviacion estandar de la base de datos
## Indica que tan dispersos alrededor de la media estan los datos
INSCRITOSIE['Edad'].std()
# Out:
# 21.70650629003199

# %%
## Varianza de la base de datos
INSCRITOSIE['Edad'].var()
# Out:
# 471.17241531919825

# %%
# librerias
import numpy as np
import matplotlib.pyplot as plt
import scipy # Modelos estadisticos
import statsmodels as sm # Modelos estadisticos
import pandas as pd
import seaborn as sns # Make sure seaborn is imported here as well
# %%

#Distribución normal
#Población: Conjunto total de elementos
# Muestra: Una parte de una población

# Size: es la cantidad de
# se distribuyen

sns.histplot(INSCRITOSIE.Edad, bins=50, alpha=0.5, color='r', label='Normal')
plt.legend()
plt.show()

# %%
#pendiente por ajustar al dataframe

x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.8, density=True, bins=30)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
INSCRITOSIE_2
# Out:
#             Fecha  Nro_inscripcion  \
# 0      2018-01-17            89536
# 1      2018-01-17            89528
# 2      2018-01-17            89535
# 3      2018-01-17            89531
# 4      2018-01-17            89533
# ...           ...              ...
# 120321 2025-03-28            94235
# 120322 2025-03-28            94240
# 120323 2025-03-28            94244
# 120324 2025-03-28            94247
# 120325 2025-03-28            94241
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                           Barrio  Edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     Etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    Eps  Estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   Tipo documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       Nacimiento     Rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              Nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      Escolaridad        Diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
## creo una copia del DF original, para posteriormente modificarlo
INSCRITOSIE = INSCRITOSIE_2

# %%
INSCRITOSIE
# Out:
#             Fecha  Nro_inscripcion  \
# 0      2018-01-17            89536
# 1      2018-01-17            89528
# 2      2018-01-17            89535
# 3      2018-01-17            89531
# 4      2018-01-17            89533
# ...           ...              ...
# 120321 2025-03-28            94235
# 120322 2025-03-28            94240
# 120323 2025-03-28            94244
# 120324 2025-03-28            94247
# 120325 2025-03-28            94241
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                       GIMNASIA INFANTIL
# 2                                       GIMNASIA INFANTIL
# 3                                                NATACIÓN
# 4                                       GIMNASIA INFANTIL
# ...                                                   ...
# 120321  FUTSALA-FUTBOL DE SALON                       ...
# 120322  FUTSALA-FUTBOL DE SALON                       ...
# 120323  FUTSALA-FUTBOL DE SALON                       ...
# 120324  FUTSALA-FUTBOL DE SALON                       ...
# 120325  FUTSALA-FUTBOL DE SALON                       ...
#
#                                                     Nivel  \
# 0       INICIACIÓN 1 (7-10 AÑOS)                      ...
# 1       PREARTISTICA MIXTO (5-6 AÑOS)                 ...
# 2       NIVEL 2 (6-15AÑOS)                            ...
# 3       CALAMARES                                     ...
# 4       INICIACIÓN 2 (8-12)                           ...
# ...                                                   ...
# 120321  JUNIOR 14/15                                  ...
# 120322  JUNIOR 14/15                                  ...
# 120323  INFANTIL 10/12                                ...
# 120324  INFANTIL 10/12                                ...
# 120325  SEMILLERO                                     ...
#
#                                           Barrio  Edad     Género  \
# 0                                            NaN    15   FEMENINO
# 1       EL DORADO                                   12   FEMENINO
# 2                                            NaN    16   FEMENINO
# 3                                            NaN     0   FEMENINO
# 4                                            NaN    15   FEMENINO
# ...                                          ...   ...        ...
# 120321  LAS ORQUÍDEAS                               14  MASCULINO
# 120322  SAN JOSÉ                                    15  MASCULINO
# 120323  EL DORADO                                   10  MASCULINO
# 120324  SAN JOSÉ                                    15  MASCULINO
# 120325  EL DORADO                                    8  MASCULINO
#
#                                                     Etnia  \
# 0                                                     NaN
# 1       Mestiza                                       ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  Mestiza                                       ...
# 120322  Mestiza                                       ...
# 120323  Mestiza                                       ...
# 120324                                          No aplica
# 120325  Blanco                                        ...
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                               No Aplica
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321                                           Migrante
# 120322                                          No Aplica
# 120323                                          No Aplica
# 120324                                          No Aplica
# 120325  Ninguna de las anteriores                     ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 2       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# ...                                                   ...  ...
# 120321  PLACA LA MERCED                               ...  ...
# 120322  PLACA LA MERCED                               ...  ...
# 120323  PLACA LA MERCED                               ...  ...
# 120324  PLACA LA MERCED                               ...  ...
# 120325  PLACA LA MERCED                               ...  ...
#
#                                    Eps  Estrato  \
# 0                                  NaN      NaN
# 1       SURA                                  3
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 120321  SAVIA SALUD EPS                       2
# 120322  SALUD TOTAL S.A. EPS                  3
# 120323  SISBEN NIVEL 3                        3
# 120324  SALUD TOTAL S.A. EPS                  3
# 120325  SURA EPS                              4
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1       ENVIGADO
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 120321  ENVIGADO
# 120322  ENVIGADO
# 120323  ENVIGADO
# 120324  ENVIGADO
# 120325  ENVIGADO
#
#                                   Tipo documento  \
# 0                                            NaN
# 1       Registro Civil
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 120321  Permiso por Protección Temporal
# 120322  Tarjeta de Identidad
# 120323  Tarjeta de Identidad
# 120324  Tarjeta de Identidad
# 120325  Tarjeta de Identidad
#
#                                       Nacimiento     Rh  \
# 0                                            NaN    NaN
# 1       ENVIGADO                                  A+
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 120321                                       NaN  O+
# 120322                                       NaN  A+
# 120323                                       NaN  O+
# 120324                                       NaN  O+
# 120325                                       NaN  O+
#
#                                              Nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120321  OTRO                                          ...
# 120322  COLOMBIA                                      ...
# 120323  COLOMBIA                                      ...
# 120324  COLOMBIA                                      ...
# 120325  COLOMBIA                                      ...
#
#                                      Escolaridad        Diversidad  \
# 0                                            NaN         No Aplica
# 1       PREESCOLAR                                       No Aplica
# 2                                            NaN         No Aplica
# 3                                            NaN         No Aplica
# 4                                            NaN         No Aplica
# ...                                          ...               ...
# 120321  BÁSICA SECUNDARIA                         No se identifica
# 120322  BÁSICA PRIMARIA                               Heterosexual
# 120323  BÁSICA PRIMARIA                               Heterosexual
# 120324  BÁSICA SECUNDARIA                                No Aplica
# 120325  BÁSICA PRIMARIA                               Heterosexual
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       NO APLICA                                     ...
# 3       NO APLICA                                     ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 120321  NO APLICA                                     ...
# 120322  NO APLICA                                     ...
# 120323  NO APLICA                                     ...
# 120324  NO APLICA                                     ...
# 120325  NO APLICA                                     ...
#
# [120326 rows x 24 columns]

# %%
# Agregar la columna 'Inscripciones' con valores de ejemplo
INSCRITOSIE['Inscripciones'] = 1

# %%
INSCRITOSIE = INSCRITOSIE.astype({'Inscripciones': 'int32'})

# %%
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120326 entries, 0 to 120325
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Fecha                 120326 non-null  datetime64[ns]
#  1   Nro_inscripcion       120326 non-null  int32
#  2   Disciplina            120326 non-null  category
#  3   Nivel                 120326 non-null  category
#  4   Barrio                104262 non-null  category
#  5   Edad                  120326 non-null  int32
#  6   Género                120326 non-null  category
#  7   Etnia                 108689 non-null  category
#  8   Poblacion             108675 non-null  category
#  9   Escenario             120326 non-null  category
#  10  Instructor            120326 non-null  category
#  11  Curso                 120326 non-null  int32
#  12  Zona                  99596 non-null   category
#  13  Fecha nacimiento      116826 non-null  datetime64[ns]
#  14  Eps                   105441 non-null  category
#  15  Estrato               107761 non-null  category
#  16  Municipio_residencia  105267 non-null  category
#  17  Tipo documento        105742 non-null  category
#  18  Nacimiento            17915 non-null   category
#  19  Rh                    107983 non-null  category
#  20  Nacionalidad          99124 non-null   category
#  21  Escolaridad           107267 non-null  category
#  22  Diversidad            119468 non-null  category
#  23  Población             120326 non-null  category
#  24  Inscripciones         120326 non-null  int32
# dtypes: category(19), datetime64[ns](2), int32(4)
# memory usage: 6.6 MB

# %%
# Agrupar por 'Disciplina' y 'Nivel' y sumar las inscripciones
agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()

# Convertir 'Disciplina' y 'Nivel' a cadena antes de la concatenación
agrupado['Disciplina_Nivel'] = agrupado['Disciplina'].astype(str) + ' - ' + agrupado['Nivel'].astype(str)

# Mostrar el DataFrame agrupado
print(agrupado)
# Out:
#                                               Disciplina  \
# 0      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 1      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 2      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 3      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 4      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# ...                                                  ...
# 25276  VOLEIBOL Y VOLEY PLAYA                        ...
# 25277  VOLEIBOL Y VOLEY PLAYA                        ...
# 25278  VOLEIBOL Y VOLEY PLAYA                        ...
# 25279  VOLEIBOL Y VOLEY PLAYA                        ...
# 25280  VOLEIBOL Y VOLEY PLAYA                        ...
#
#                                                    Nivel  Inscripciones  \
# 0                                                   2024              0
# 1       I (6-12)                                     ...             47
# 2      ABIERTO                                       ...              0
# 3      ACONDICIONAMIENTO FISICO-MASIFICACION         ...              0
# 4      ACT ACUATICAS   2                             ...              0
# ...                                                  ...            ...
# 25276  VIII NIÑOS                                    ...              0
# 25277  VIII-IX-FORMATIVO (NIÑOS)                     ...              0
# 25278                                           VOLEIBOL              0
# 25279  YOGA                                          ...              0
# 25280  YOGA                                          ...              0
#
#                                         Disciplina_Nivel
# 0      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 1      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 2      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 3      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# 4      ACTIVIDADES ACUATICAS - ALTO DE LOS SUEÑOS    ...
# ...                                                  ...
# 25276  VOLEIBOL Y VOLEY PLAYA                        ...
# 25277  VOLEIBOL Y VOLEY PLAYA                        ...
# 25278  VOLEIBOL Y VOLEY PLAYA                        ...
# 25279  VOLEIBOL Y VOLEY PLAYA                        ...
# 25280  VOLEIBOL Y VOLEY PLAYA                        ...
#
# [25281 rows x 4 columns]
# <ipython-input-281-6376b598e13a>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()

# %%
## # verificar valores únicos en Disciplina
print(INSCRITOSIE['Disciplina'].unique())
# Out:
# ['Gimnasia Infantil', 'Natación', 'Taekwondo', 'Tenis De Campo', 'Escuela De Futbol De Interes Social- Efisae', ..., 'Ultimate', 'Deporte Adaptado', 'Tejo', 'Programa Sin Barreras', 'Actividades Sede Palmeras Deport. Y Activ Fis...]
# Length: 53
# Categories (53, object): ['Actividades Acuaticas - Alto De Los Sueños', 'Actividades Sede Palmeras Deport. Y Activ Fis...,
#                           'Actividades Sub Acuaticas', 'Ajedrez', ..., 'Torneos', 'Trepadores A La Catedral',
#                           'Ultimate', 'Voleibol Y Voley Playa']

# %%
## # verificar valores únicos en Disciplina
print(INSCRITOSIE['Nivel'].unique())
# Out:
# ['Iniciación 1 (7-10 Años)', 'Preartistica Mixto (5-6 Años)', 'Nivel 2 (6-15Años)', 'Calamares', 'Iniciación 2 (8-12)', ..., 'Preartistica Basico (7 A 10 Años)', 'Iniciacion Basica (5 A 6 Años)', 'Jovenes Basico (11 Años Y Más)', 'Masculino Avanzado (10 Años Y Más)', 'Act. Acuaticas - Ambientacion']
# Length: 472
# Categories (472, object): [2024, 'Abierto', 'Acondicionamiento Fisico-Masificacion',
#                            'Act Acuaticas 1', ..., 'Viii Niños', 'Viii-Ix-Formativo (Niños)',
#                            'Voleibol', 'Yoga']

# %%
# Convert 'Disciplina' and 'Nivel' to categorical (if not already) to ensure they are treated as distinct categories
# even if they look like numbers.
INSCRITOSIE['Disciplina'] = pd.Categorical(INSCRITOSIE['Disciplina'])
INSCRITOSIE['Nivel'] = pd.Categorical(INSCRITOSIE['Nivel'])

# Now perform the groupby and sum
agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()

# The rest of your code remains the same...
agrupado['Disciplina_Nivel'] = agrupado['Disciplina'].astype(str) + ' - ' + agrupado['Nivel'].astype(str)

# ... (the rest of your plotting code)
# Out:
# <ipython-input-290-0d4a6f19221c>:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Asegúrate de que INSCRITOSIE es un DataFrame válido
INSCRITOSIE = pd.DataFrame(INSCRITOSIE)

# Agrupar por 'Disciplina' y 'Nivel' y sumar las inscripciones
agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()

# Crear una nueva columna que combine 'Disciplina' y 'Nivel'
agrupado['Disciplina_Nivel'] = agrupado['Disciplina'].astype(str) + ' - ' + agrupado['Nivel'].astype(str)

# Graficar los resultados con seaborn
plt.figure(figsize=(12, 8))  # Aumentar el tamaño de la figura
sns.barplot(data=agrupado, x='Disciplina_Nivel', y='Inscripciones', palette='Blues')  # Cambiar la paleta
plt.title('Inscripciones por Disciplina y Nivel')
plt.xlabel('Disciplina - Nivel')
plt.ylabel('Número de Inscripciones')
plt.xticks(rotation=45, ha='right')  # Rotar etiquetas del eje x para mejor legibilidad
plt.tight_layout()  # Ajustar el layout para que no se corten las etiquetas
plt.show()
# Out:
# <ipython-input-294-43cdcd8c4286>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()
# <ipython-input-294-43cdcd8c4286>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=agrupado, x='Disciplina_Nivel', y='Inscripciones', palette='Blues')  # Cambiar la paleta

# %%
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120326 entries, 0 to 120325
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Fecha                 120326 non-null  datetime64[ns]
#  1   Nro_inscripcion       120326 non-null  int32
#  2   Disciplina            120326 non-null  category
#  3   Nivel                 120326 non-null  category
#  4   Barrio                104262 non-null  category
#  5   Edad                  120326 non-null  int32
#  6   Género                120326 non-null  category
#  7   Etnia                 108689 non-null  category
#  8   Poblacion             108675 non-null  category
#  9   Escenario             120326 non-null  category
#  10  Instructor            120326 non-null  category
#  11  Curso                 120326 non-null  int32
#  12  Zona                  99596 non-null   category
#  13  Fecha nacimiento      116826 non-null  datetime64[ns]
#  14  Eps                   105441 non-null  category
#  15  Estrato               107761 non-null  category
#  16  Municipio_residencia  105267 non-null  category
#  17  Tipo documento        105742 non-null  category
#  18  Nacimiento            17915 non-null   category
#  19  Rh                    107983 non-null  category
#  20  Nacionalidad          99124 non-null   category
#  21  Escolaridad           107267 non-null  category
#  22  Diversidad            119468 non-null  category
#  23  Población             120326 non-null  category
#  24  Inscripciones         120326 non-null  int32
# dtypes: category(19), datetime64[ns](2), int32(4)
# memory usage: 6.6 MB

# %%
INSCRITOSIE.describe()
# Out:
#                                Fecha  Nro_inscripcion           Edad  \
# count                         120326     1.203260e+05  120326.000000
# mean   2022-04-22 06:10:26.498013696     6.343167e+04      25.640585
# min              2018-01-17 00:00:00     1.980000e+02     -75.000000
# 25%              2021-02-02 00:00:00     3.053125e+04      11.000000
# 50%              2022-06-14 00:00:00     5.992500e+04      15.000000
# 75%              2024-03-12 00:00:00     9.102275e+04      39.000000
# max              2025-03-28 00:00:00     2.018045e+07     125.000000
# std                              NaN     1.781892e+05      21.850769
#
#               Curso               Fecha nacimiento  Inscripciones
# count  1.203260e+05                         116826       120326.0
# mean   2.021980e+07  1998-05-02 16:14:11.235170304            1.0
# min    2.018001e+07            1900-01-01 00:00:00            1.0
# 25%    2.021000e+07            1984-02-17 00:00:00            1.0
# 50%    2.022125e+07            2008-12-08 00:00:00            1.0
# 75%    2.024038e+07            2013-09-16 00:00:00            1.0
# max    2.025122e+07            2099-09-10 00:00:00            1.0
# std    2.147757e+04                            NaN            0.0

# %%
print(INSCRITOSIE.head())  # Muestra las primeras filas del DataFrame
print(INSCRITOSIE.info())  # Información sobre el DataFrame
# Out:
#        Fecha  Nro_inscripcion         Disciplina  \
# 0 2018-01-17            89536  Gimnasia Infantil
# 1 2018-01-17            89528  Gimnasia Infantil
# 2 2018-01-17            89535  Gimnasia Infantil
# 3 2018-01-17            89531           Natación
# 4 2018-01-17            89533  Gimnasia Infantil
#
#                            Nivel     Barrio  Edad    Género    Etnia  \
# 0       Iniciación 1 (7-10 Años)        NaN    15  Femenino      NaN
# 1  Preartistica Mixto (5-6 Años)  El Dorado    12  Femenino  Mestiza
# 2             Nivel 2 (6-15Años)        NaN    16  Femenino      NaN
# 3                      Calamares        NaN     0  Femenino      NaN
# 4            Iniciación 2 (8-12)        NaN    15  Femenino      NaN
#
#    Poblacion                                 Escenario  ... Estrato  \
# 0        NaN  Salon De Gimnasia Infantil Polideportivo  ...     NaN
# 1  No Aplica  Salon De Gimnasia Infantil Polideportivo  ...       3
# 2        NaN  Salon De Gimnasia Infantil Polideportivo  ...     NaN
# 3        NaN                 Piscina Polideportivo Sur  ...     NaN
# 4        NaN  Salon De Gimnasia Infantil Polideportivo  ...     NaN
#
#    Municipio_residencia  Tipo documento Nacimiento   Rh Nacionalidad  \
# 0                   NaN             NaN        NaN  NaN          NaN
# 1              Envigado  Registro Civil   Envigado   A+          NaN
# 2                   NaN             NaN        NaN  NaN          NaN
# 3                   NaN             NaN        NaN  NaN          NaN
# 4                   NaN             NaN        NaN  NaN          NaN
#
#   Escolaridad Diversidad  Población Inscripciones
# 0         NaN  No Aplica  No Aplica             1
# 1  Preescolar  No Aplica  No Aplica             1
# 2         NaN  No Aplica  No Aplica             1
# 3         NaN  No Aplica  No Aplica             1
# 4         NaN  No Aplica  No Aplica             1
#
# [5 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120326 entries, 0 to 120325
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Fecha                 120326 non-null  datetime64[ns]
#  1   Nro_inscripcion       120326 non-null  int64
#  2   Disciplina            120326 non-null  category
#  3   Nivel                 120326 non-null  category
#  4   Barrio                104262 non-null  category
#  5   Edad                  120326 non-null  int64
#  6   Género                120326 non-null  category
#  7   Etnia                 108689 non-null  category
#  8   Poblacion             108675 non-null  category
#  9   Escenario             120326 non-null  object
#  10  Instructor            120326 non-null  object
#  11  Curso                 120326 non-null  int64
#  12  Zona                  99596 non-null   object
#  13  Fecha nacimiento      116826 non-null  datetime64[ns]
#  14  Eps                   105441 non-null  object
#  15  Estrato               107761 non-null  category
#  16  Municipio_residencia  105267 non-null  object
#  17  Tipo documento        105742 non-null  category
#  18  Nacimiento            17915 non-null   object
#  19  Rh                    107983 non-null  object
#  20  Nacionalidad          99124 non-null   object
#  21  Escolaridad           107267 non-null  object
#  22  Diversidad            119468 non-null  category
#  23  Población             120326 non-null  category
#  24  Inscripciones         120326 non-null  int32
# dtypes: category(10), datetime64[ns](2), int32(1), int64(3), object(9)
# memory usage: 14.6+ MB
# None

# %%
agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()
# Out:
# <ipython-input-296-1af26f3397c7>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agrupado = INSCRITOSIE.groupby(['Disciplina', 'Nivel'], as_index=False)['Inscripciones'].sum()

# %%
agrupado['Disciplina_Nivel'] = agrupado['Disciplina'].astype(str) + ' - ' + agrupado['Nivel'].astype(str)

# %%
plt.figure(figsize=(12, 8))  # Aumentar el tamaño de la figura
sns.barplot(data=agrupado, x='Disciplina_Nivel', y='Inscripciones', palette='Blues')  # Cambiar la paleta
plt.title('Inscripciones por Disciplina y Nivel')
plt.xlabel('Disciplina - Nivel')
plt.ylabel('Número de Inscripciones')
plt.xticks(rotation=45, ha='right')  # Rotar etiquetas del eje x para mejor legibilidad
plt.tight_layout()  # Ajustar el layout para que no se corten las etiquetas
plt.show()
# Out:
# <ipython-input-298-61b33f80a7e8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=agrupado, x='Disciplina_Nivel', y='Inscripciones', palette='Blues')  # Cambiar la paleta

# %%
print(agrupado.isnull().sum())  # Verificar valores nulos
# Out:
# Disciplina          0
# Nivel               0
# Inscripciones       0
# Disciplina_Nivel    0
# dtype: int64

# %%
subconjunto = agrupado.head(10)  # Tomar solo las primeras 10 filas
sns.barplot(data=subconjunto, x='Disciplina_Nivel', y='Inscripciones', palette='Blues')
plt.show()
# Out:
# <ipython-input-300-6f52be2f8689>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=subconjunto, x='Disciplina_Nivel', y='Inscripciones', palette='Blues')
